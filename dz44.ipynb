# %% [markdown]
# # Домашнее задание 3
#
# Используя источник **rate**, напишите код, который создаст дополнительный столбец, который будет выводить сумму только нечетных чисел

# %%
import pyspark
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.window import Window
from pyspark.sql.functions import col, sum
from pprint import pprint

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Создаем SparkSession
spark = SparkSession.builder.appName("Homework3").getOrCreate()
# Создаем поток данных с использованием источника данных `rate`
streaming_df = spark \
.readStream \
.format("rate") \
.option("rowsPerSecond", 1) \
.load()
# Оставляем только те строки, где значение нечетное
filtered_df = streaming_df.filter(col("value") % 2 == 1)
# Суммирование
sum_odds = filtered_df.agg(sum("value"))
# Выводим результат
query = sum_odds \
.writeStream \
.outputMode("complete") \
.format("console") \
.start()
query.awaitTermination()
# Out:
# 24/04/19 14:59:51 WARN Utils: Your hostname, alexey-Aspire-A315-42 resolves to a loopback address: 127.0.1.1; using 192.168.1.70 instead (on interface wlp4s0)
# 24/04/19 14:59:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/alexey/.local/lib/python3.8/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.4.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/19 14:59:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/04/19 14:59:56 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-3bd6ca6e-c5cf-40f2-860c-62a0de007a74. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 24/04/19 14:59:56 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |      null|
# +----------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |         1|
# +----------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |         1|
# +----------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |         4|
# +----------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |         4|
# +----------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |         9|
# +----------+
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |         9|
# +----------+
#
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        16|
# +----------+
#
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        16|
# +----------+
#
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        25|
# +----------+
#
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        25|
# +----------+
#
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        36|
# +----------+
#
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        36|
# +----------+
#
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        49|
# +----------+
#
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        49|
# +----------+
#
# -------------------------------------------
# Batch: 15
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        64|
# +----------+
#
# -------------------------------------------
# Batch: 16
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        64|
# +----------+
#
# -------------------------------------------
# Batch: 17
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        81|
# +----------+
#
# -------------------------------------------
# Batch: 18
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |        81|
# +----------+
#
# -------------------------------------------
# Batch: 19
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       100|
# +----------+
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       100|
# +----------+
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       121|
# +----------+
#
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       121|
# +----------+
#
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       144|
# +----------+
#
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       144|
# +----------+
#
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       169|
# +----------+
#
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       169|
# +----------+
#
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       196|
# +----------+
#
# -------------------------------------------
# Batch: 28
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       196|
# +----------+
#
# -------------------------------------------
# Batch: 29
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       225|
# +----------+
#
# -------------------------------------------
# Batch: 30
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       225|
# +----------+
#
# -------------------------------------------
# Batch: 31
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       256|
# +----------+
#
# -------------------------------------------
# Batch: 32
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       256|
# +----------+
#
# -------------------------------------------
# Batch: 33
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       289|
# +----------+
#
# -------------------------------------------
# Batch: 34
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       289|
# +----------+
#
# -------------------------------------------
# Batch: 35
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       324|
# +----------+
#
# -------------------------------------------
# Batch: 36
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       324|
# +----------+
#
# -------------------------------------------
# Batch: 37
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       361|
# +----------+
#
# -------------------------------------------
# Batch: 38
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       361|
# +----------+
#
# -------------------------------------------
# Batch: 39
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       400|
# +----------+
#
# -------------------------------------------
# Batch: 40
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       400|
# +----------+
#
# -------------------------------------------
# Batch: 41
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       441|
# +----------+
#
# -------------------------------------------
# Batch: 42
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       441|
# +----------+
#
# -------------------------------------------
# Batch: 43
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       484|
# +----------+
#
# -------------------------------------------
# Batch: 44
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       484|
# +----------+
#
# -------------------------------------------
# Batch: 45
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       529|
# +----------+
#
# -------------------------------------------
# Batch: 46
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       529|
# +----------+
#
# -------------------------------------------
# Batch: 47
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       576|
# +----------+
#
# -------------------------------------------
# Batch: 48
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       576|
# +----------+
#
# -------------------------------------------
# Batch: 49
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       625|
# +----------+
#
# -------------------------------------------
# Batch: 50
# -------------------------------------------
# +----------+
# |sum(value)|
# +----------+
# |       625|
# +----------+
